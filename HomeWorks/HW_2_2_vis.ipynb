# %% [markdown]
# Проведите анализ файла 2017_jun_final.csv. Файл содержит результаты опроса разработчиков в июне 2017 года.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Прочитайте файл 2017_jun_final.csv с помощью метода read_csv

# %%
df = pd.read_csv('2017_jun_final.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8704 entries, 0 to 8703
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   N                                 8704 non-null   int64
#  1   Должность                         8704 non-null   object
#  2   Язык.программирования             4854 non-null   object
#  3   Специализация                     1485 non-null   object
#  4   Общий.опыт.работы                 8704 non-null   object
#  5   Опыт.работы.на.текущем.месте      8704 non-null   object
#  6   Зарплата.в.месяц                  8704 non-null   int64
#  7   Изменение.зарплаты.за.12.месяцев  8704 non-null   int64
#  8   Город                             8704 non-null   object
#  9   Размер.компании                   8704 non-null   object
#  10  Тип.компании                      8704 non-null   object
#  11  Пол                               8704 non-null   object
#  12  Возраст                           8704 non-null   int64
#  13  Образование                       8704 non-null   object
#  14  Университет                       8346 non-null   object
#  15  Еще.студент                       8704 non-null   bool
#  16  Уровень.английского               8704 non-null   object
#  17  Предметная.область                8481 non-null   object
#  18  Дата.заполнения                   8704 non-null   object
#  19  User.Agent                        8704 non-null   object
#  20  exp                               8704 non-null   float64
#  21  current_job_exp                   8704 non-null   float64
#  22  salary                            8704 non-null   int64
#  23  Валюта                            10 non-null     object
#  24  cls                               7130 non-null   object
# dtypes: bool(1), float64(2), int64(5), object(17)
# memory usage: 1.6+ MB

# %% [markdown]
# Прочитайте полученную таблицу используя метод head

# %%
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#     N                 Должность Язык.программирования Специализация  \
# 0   1        Junior QA engineer                   NaN     Manual QA
# 1   2        Junior QA engineer                   NaN     Manual QA
# 2   3         Software Engineer               C#/.NET           NaN
# 3   4         Software Engineer            JavaScript           NaN
# 4   5  Senior Software Engineer            JavaScript           NaN
# 5   6           Project manager                   NaN           NaN
# 6   7  Junior Software Engineer               C#/.NET           NaN
# 7   8  Senior Software Engineer                   C++           NaN
# 8   9  Junior Software Engineer                  Java           NaN
# 9  10                  Sysadmin                   NaN           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
# 5                 1                            1               400
# 6                 1             меньше 3 месяцев               600
# 7                 6                            1              3300
# 8               0.5                          0.5               550
# 9                 5                            2               520
#
#    Изменение.зарплаты.за.12.месяцев        Город     Размер.компании  \
# 0                                 0      Харьков       до 10 человек
# 1                               130      Харьков  свыше 1000 человек
# 2                               800         Киев     до 1000 человек
# 3                               400       Одесса      до 200 человек
# 4                               500       Другой       до 10 человек
# 5                                 0         Киев       до 10 человек
# 6                               100  Хмельницкий       до 50 человек
# 7                               500         Киев       до 10 человек
# 8                               550      Харьков  свыше 1000 человек
# 9                                20         Киев       до 10 человек
#
#      Тип.компании      Пол  Возраст           Образование  \
# 0  Аутсорсинговая  женский       20  Незаконченное высшее
# 1  Аутсорсинговая  женский       21  Незаконченное высшее
# 2  Аутсорсинговая  мужской       26                Высшее
# 3     Продуктовая  мужской       30               Среднее
# 4     Продуктовая  мужской       30    Техникум / Колледж
# 5         Стартап  мужской       21  Незаконченное высшее
# 6  Аутсорсинговая  мужской       23                Высшее
# 7     Продуктовая  мужской       28                Высшее
# 8  Аутсорсинговая  женский       23                Высшее
# 9     Продуктовая  мужской       29                Высшее
#
#             Университет  Еще.студент Уровень.английского  \
# 0                  ХНЭУ         True       ниже среднего
# 1                  ХНЭУ         True       выше среднего
# 2                ДонНТУ        False             средний
# 3                   NaN        False       ниже среднего
# 4                   NaN        False             средний
# 5                   НАУ         True             средний
# 6  ХНУ [г. Хмельницкий]        False       ниже среднего
# 7            НТУУ «КПИ»        False       выше среднего
# 8      ХНУ им. Каразина        False             средний
# 9  НГУ [Днепропетровск]        False             средний
#
#                      Предметная.область      Дата.заполнения  \
# 0                         iOS,eCommerce  12/06/2017 12:38:08
# 1                        Веб-разработка  12/06/2017 12:42:51
# 2  Веб-разработка,Корпоративные системы  12/06/2017 13:02:47
# 3   Desktop Applications,Веб-разработка  12/06/2017 13:03:01
# 4   Desktop Applications,Веб-разработка  12/06/2017 13:03:47
# 5                        Веб-разработка  12/06/2017 13:04:04
# 6                        Веб-разработка  12/06/2017 13:04:26
# 7                                Другое  12/06/2017 13:04:27
# 8                        Веб-разработка  12/06/2017 13:04:28
# 9            Системное программирование  12/06/2017 13:05:17
#
#                                           User.Agent   exp  current_job_exp  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.5              0.5
# 1  Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...   0.0              0.0
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.0              1.0
# 3  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.0              4.0
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  10.0              0.5
# 5  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:53.0) G...   1.0              1.0
# 6  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   1.0              0.0
# 7  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:53....   6.0              1.0
# 8  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:53....   0.5              0.5
# 9  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; ...   5.0              2.0
#
#    salary Валюта  cls
# 0     400    NaN   QA
# 1     430    NaN   QA
# 2    2500    NaN  DEV
# 3    2000    NaN  DEV
# 4    4500    NaN  DEV
# 5     400    NaN   PM
# 6     600    NaN  DEV
# 7    3300    NaN  DEV
# 8     550    NaN  DEV
# 9     520    NaN  NaN
# Warning: Total number of columns (25) exceeds max_columns (20) limiting to first (20) columns.

# %% [markdown]
# Определите размер таблицы с помощью метода shape

# %%
df.shape
# Out:
# (8704, 25)

# %% [markdown]
# Определите типы всех столбцов с помощью dataframe.dtypes

# %%
df.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# current_job_exp                     float64
# salary                                int64
# Валюта                               object
# cls                                  object
# dtype: object

# %% [markdown]
# Посчитайте, какая доля пропусков содержится в каждой колонке (используйте методы isnull и sum)

# %%
df.isna().sum()
# Out:
# N                                      0
# Должность                              0
# Язык.программирования               3850
# Специализация                       7219
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Университет                          358
# Еще.студент                            0
# Уровень.английского                    0
# Предметная.область                   223
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# Валюта                              8694
# cls                                 1574
# dtype: int64

# %% [markdown]
# Удалите все столбцы с пропусками, кроме столбца "Язык.программирования"

# %%
colomn_list = df.dropna(axis='columns').columns.to_list()
colomn_list.append('Язык.программирования')
df = df[(colomn_list)].copy()
df
# Out:
#          N                 Должность Общий.опыт.работы  \
# 0        1        Junior QA engineer               0.5
# 1        2        Junior QA engineer  меньше 3 месяцев
# 2        3         Software Engineer                 4
# 3        4         Software Engineer                 5
# 4        5  Senior Software Engineer    10 и более лет
# ...    ...                       ...               ...
# 8699  8700               QA engineer                 1
# 8700  8701                 Marketing               0.5
# 8701  8702  Junior Software Engineer                 1
# 8702  8703                 Team lead                 6
# 8703  8704  Senior Software Engineer                 7
#
#      Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0                             0.5               400
# 1                меньше 3 месяцев               430
# 2                               1              2500
# 3                               4              2000
# 4                             0.5              4500
# ...                           ...               ...
# 8699             меньше 3 месяцев               700
# 8700                          0.5               400
# 8701                          0.5               800
# 8702                            4              2600
# 8703                            2              5000
#
#       Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  \
# 0                                    0  Харьков       до 10 человек
# 1                                  130  Харьков  свыше 1000 человек
# 2                                  800     Киев     до 1000 человек
# 3                                  400   Одесса      до 200 человек
# 4                                  500   Другой       до 10 человек
# ...                                ...      ...                 ...
# 8699                               700   Одесса       до 50 человек
# 8700                               120     Киев       до 50 человек
# 8701                               500    Львов       до 10 человек
# 8702                                 0    Днепр  свыше 1000 человек
# 8703                               800   Одесса     до 1000 человек
#
#          Тип.компании      Пол  Возраст           Образование  Еще.студент  \
# 0      Аутсорсинговая  женский       20  Незаконченное высшее         True
# 1      Аутсорсинговая  женский       21  Незаконченное высшее         True
# 2      Аутсорсинговая  мужской       26                Высшее        False
# 3         Продуктовая  мужской       30               Среднее        False
# 4         Продуктовая  мужской       30    Техникум / Колледж        False
# ...               ...      ...      ...                   ...          ...
# 8699   Аутсорсинговая  мужской       23                Высшее        False
# 8700      Продуктовая  женский       22                Высшее        False
# 8701  Аутстаффинговая  мужской       30  Незаконченное высшее        False
# 8702   Аутсорсинговая  мужской       34                Высшее        False
# 8703      Продуктовая  мужской       28                Высшее        False
#
#      Уровень.английского      Дата.заполнения  \
# 0          ниже среднего  12/06/2017 12:38:08
# 1          выше среднего  12/06/2017 12:42:51
# 2                средний  12/06/2017 13:02:47
# 3          ниже среднего  12/06/2017 13:03:01
# 4                средний  12/06/2017 13:03:47
# ...                  ...                  ...
# 8699             средний  12/07/2017 15:45:24
# 8700       ниже среднего  12/07/2017 17:00:06
# 8701       выше среднего  12/07/2017 17:32:26
# 8702         продвинутый  12/07/2017 18:14:59
# 8703       выше среднего  12/07/2017 21:28:57
#
#                                              User.Agent   exp  \
# 0     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.5
# 1     Mozilla/5.0 (iPad; CPU OS 10_2_1 like Mac OS X...   0.0
# 2     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.0
# 3     Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.0
# 4     Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  10.0
# ...                                                 ...   ...
# 8699  Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54....   1.0
# 8700  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   0.5
# 8701  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0
# 8702  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...   6.0
# 8703  Mozilla/5.0 (iPad; CPU OS 10_3_2 like Mac OS X...   7.0
#
#       current_job_exp  salary Язык.программирования
# 0                 0.5     400                   NaN
# 1                 0.0     430                   NaN
# 2                 1.0    2500               C#/.NET
# 3                 4.0    2000            JavaScript
# 4                 0.5    4500            JavaScript
# ...               ...     ...                   ...
# 8699              0.0     700                   NaN
# 8700              0.5     400                   NaN
# 8701              0.5     800            Ruby/Rails
# 8702              4.0    2600                   NaN
# 8703              2.0    5000                  Java
#
# [8704 rows x 20 columns]

# %% [markdown]
# Опять посчитайте, какая доля пропусков содержится в каждой колонке и убедитесь, что остался только столбец "Язык.программирования"

# %%
df.isna().sum()
# Out:
# N                                      0
# Должность                              0
# Общий.опыт.работы                      0
# Опыт.работы.на.текущем.месте           0
# Зарплата.в.месяц                       0
# Изменение.зарплаты.за.12.месяцев       0
# Город                                  0
# Размер.компании                        0
# Тип.компании                           0
# Пол                                    0
# Возраст                                0
# Образование                            0
# Еще.студент                            0
# Уровень.английского                    0
# Дата.заполнения                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# Язык.программирования               3850
# dtype: int64

# %% [markdown]
# Определите новый размер таблицы с помощью метода shape

# %%
df.shape
# Out:
# (8704, 20)

# %% [markdown]
# Создайте новую таблицу python_data в которой будут только строки со специалистами указавшими язык программирования Python

# %%
new_table = df.dropna()
new_table
# Out:
#          N                 Должность Общий.опыт.работы  \
# 2        3         Software Engineer                 4
# 3        4         Software Engineer                 5
# 4        5  Senior Software Engineer    10 и более лет
# 6        7  Junior Software Engineer                 1
# 7        8  Senior Software Engineer                 6
# ...    ...                       ...               ...
# 8692  8693         Software Engineer                 5
# 8694  8695  Junior Software Engineer                 1
# 8695  8696         Software Engineer                 1
# 8701  8702  Junior Software Engineer                 1
# 8703  8704  Senior Software Engineer                 7
#
#      Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 2                               1              2500
# 3                               4              2000
# 4                             0.5              4500
# 6                меньше 3 месяцев               600
# 7                               1              3300
# ...                           ...               ...
# 8692                            1              3500
# 8694                            1               550
# 8695                          0.5              1500
# 8701                          0.5               800
# 8703                            2              5000
#
#       Изменение.зарплаты.за.12.месяцев        Город  Размер.компании  \
# 2                                  800         Киев  до 1000 человек
# 3                                  400       Одесса   до 200 человек
# 4                                  500       Другой    до 10 человек
# 6                                  100  Хмельницкий    до 50 человек
# 7                                  500         Киев    до 10 человек
# ...                                ...          ...              ...
# 8692                               650     Удаленно   до 200 человек
# 8694                               550      Харьков   до 200 человек
# 8695                              1000         Киев    до 10 человек
# 8701                               500        Львов    до 10 человек
# 8703                               800       Одесса  до 1000 человек
#
#          Тип.компании      Пол  Возраст           Образование  Еще.студент  \
# 2      Аутсорсинговая  мужской       26                Высшее        False
# 3         Продуктовая  мужской       30               Среднее        False
# 4         Продуктовая  мужской       30    Техникум / Колледж        False
# 6      Аутсорсинговая  мужской       23                Высшее        False
# 7         Продуктовая  мужской       28                Высшее        False
# ...               ...      ...      ...                   ...          ...
# 8692   Аутсорсинговая  женский       28                Высшее        False
# 8694   Аутсорсинговая  мужской       23                Высшее        False
# 8695          Стартап  мужской       29                Высшее        False
# 8701  Аутстаффинговая  мужской       30  Незаконченное высшее        False
# 8703      Продуктовая  мужской       28                Высшее        False
#
#      Уровень.английского      Дата.заполнения  \
# 2                средний  12/06/2017 13:02:47
# 3          ниже среднего  12/06/2017 13:03:01
# 4                средний  12/06/2017 13:03:47
# 6          ниже среднего  12/06/2017 13:04:26
# 7          выше среднего  12/06/2017 13:04:27
# ...                  ...                  ...
# 8692             средний  12/07/2017 13:26:49
# 8694       ниже среднего  12/07/2017 14:14:33
# 8695             средний  12/07/2017 14:39:21
# 8701       выше среднего  12/07/2017 17:32:26
# 8703       выше среднего  12/07/2017 21:28:57
#
#                                              User.Agent   exp  \
# 2     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   4.0
# 3     Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...   5.0
# 4     Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_2 like...  10.0
# 6     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   1.0
# 7     Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:53....   6.0
# ...                                                 ...   ...
# 8692  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_5...   5.0
# 8694  Mozilla/5.0 (Windows NT 10.0; WOW64; rv:54.0) ...   1.0
# 8695  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0
# 8701  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...   1.0
# 8703  Mozilla/5.0 (iPad; CPU OS 10_3_2 like Mac OS X...   7.0
#
#       current_job_exp  salary Язык.программирования
# 2                 1.0    2500               C#/.NET
# 3                 4.0    2000            JavaScript
# 4                 0.5    4500            JavaScript
# 6                 0.0     600               C#/.NET
# 7                 1.0    3300                   C++
# ...               ...     ...                   ...
# 8692              1.0    3500                  Java
# 8694              1.0     550               C#/.NET
# 8695              0.5    1500                Python
# 8701              0.5     800            Ruby/Rails
# 8703              2.0    5000                  Java
#
# [4854 rows x 20 columns]

# %% [markdown]
# Определите размер таблицы python_data с помощью метода shape

# %%
new_table.shape
# Out:
# (4854, 20)

# %% [markdown]
# Используя метод groupby выполните группировку по столбцу "Должность"

# %%
df.groupby(by="Должность")

# %% [markdown]
# Создайте новый DataFrame, где для сгруппированных данных по столбцу "Должность", выполните агрегацию данных с помощью метода agg и найдите минимальное и максимальное значение в столбце "Зарплата.в.месяц"

# %%
grouped_position = df.groupby(by="Должность").agg(['max', 'min'])
grouped_position['Зарплата.в.месяц']
# Out:
#                                               max   min
# Должность
# Business analyst                             5000   200
# DBA                                          6000   380
# Data Scientist / Data Analyst                8000   150
# Designer                                     4000   100
# DevOps                                      10000   194
# Director of Engineering / Program Director  34000  1500
# ERP / CRM                                    6000   100
# Game designer                                6800   150
# HR                                           7000   100
# HTML coder                                   3000   154
# Junior QA engineer                           2000    96
# Junior Software Engineer                     2600    75
# Marketing                                    4000   100
# Product Manager                              5000   250
# Project manager                              8000   190
# QA Tech Lead                                 6000   430
# QA engineer                                  2900   150
# Research Engineer                            4000   114
# Sales manager                                2300   120
# Scrum Master                                 4500   370
# Security Specialist                          4000   300
# Senior Project Manager / Program Manager     9100   200
# Senior QA engineer                           6000   400
# Senior Software Engineer                     9200   350
# Software Engineer                            7000   100
# Support                                      3650   138
# Sysadmin                                     3000    90
# System Architect                            10000   400
# Talent Researcher                            1700   100
# Team lead                                    7000   300
# Technical Lead                              18000   500
# Technical writer                             3000   200

# %% [markdown]
# ***Візуалізація розподілу зарплати по спеціалізаціях***

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.stripplot(y='Должность', x='Зарплата.в.месяц', data=df)
# Out:
# <AxesSubplot:xlabel='Зарплата.в.месяц', ylabel='Должность'>

# %% [markdown]
# ***Візуалізація лінії регресії між досвідом та зарплатнею***

# %%
df.corr()
# Out:
#                                          N  Зарплата.в.месяц  \
# N                                 1.000000         -0.055444
# Зарплата.в.месяц                 -0.055444          1.000000
# Изменение.зарплаты.за.12.месяцев -0.044172          0.336692
# Возраст                          -0.009122          0.357542
# Еще.студент                       0.022491         -0.210514
# exp                              -0.022223          0.642521
# current_job_exp                   0.002076          0.277072
# salary                           -0.055444          1.000000
#
#                                   Изменение.зарплаты.за.12.месяцев   Возраст  \
# N                                                        -0.044172 -0.009122
# Зарплата.в.месяц                                          0.336692  0.357542
# Изменение.зарплаты.за.12.месяцев                          1.000000 -0.075462
# Возраст                                                  -0.075462  1.000000
# Еще.студент                                              -0.000235 -0.427707
# exp                                                       0.014913  0.591248
# current_job_exp                                          -0.123082  0.366926
# salary                                                    0.336692  0.357542
#
#                                   Еще.студент       exp  current_job_exp  \
# N                                    0.022491 -0.022223         0.002076
# Зарплата.в.месяц                    -0.210514  0.642521         0.277072
# Изменение.зарплаты.за.12.месяцев    -0.000235  0.014913        -0.123082
# Возраст                             -0.427707  0.591248         0.366926
# Еще.студент                          1.000000 -0.281642        -0.170216
# exp                                 -0.281642  1.000000         0.515799
# current_job_exp                     -0.170216  0.515799         1.000000
# salary                              -0.210514  0.642521         0.277072
#
#                                     salary
# N                                -0.055444
# Зарплата.в.месяц                  1.000000
# Изменение.зарплаты.за.12.месяцев  0.336692
# Возраст                           0.357542
# Еще.студент                      -0.210514
# exp                               0.642521
# current_job_exp                   0.277072
# salary                            1.000000

# %%
sns.regplot(x='Зарплата.в.месяц', y='exp', color='r', data=df)
plt.xlim(0, 10000)
# Out:
# (0.0, 10000.0)

# %% [markdown]
# ***Візуалізація розподілу зарплатні в залежності від віку***

# %%
sns.stripplot(x='Зарплата.в.месяц', y='Возраст', data=df)
# Out:
# <AxesSubplot:xlabel='Зарплата.в.месяц', ylabel='Возраст'>

# %% [markdown]
# Создайте функцию fill_avg_salary которая будет возвращать среднее значение заработной платы в месяц. Используйте ее для метода apply и создайте новый столбик "avg"

# %%
def fill_avg_salary(salary):
    return np.mean(salary)

grouped_position['avg'] = df.groupby(by="Должность")['Зарплата.в.месяц'].apply(fill_avg_salary)
grouped_position[['Зарплата.в.месяц','avg']]
# Out:
#                                            Зарплата.в.месяц                avg
#                                                         max   min
# Должность
# Business analyst                                       5000   200  1551.500000
# DBA                                                    6000   380  1653.269231
# Data Scientist / Data Analyst                          8000   150  1544.240506
# Designer                                               4000   100  1134.161435
# DevOps                                                10000   194  2162.688235
# Director of Engineering / Program Director            34000  1500  5066.363636
# ERP / CRM                                              6000   100  1370.833333
# Game designer                                          6800   150  1455.277778
# HR                                                     7000   100   850.283401
# HTML coder                                             3000   154   550.993590
# Junior QA engineer                                     2000    96   482.774752
# Junior Software Engineer                               2600    75   605.658594
# Marketing                                              4000   100   861.282609
# Product Manager                                        5000   250  2054.471264
# Project manager                                        8000   190  1512.846361
# QA Tech Lead                                           6000   430  2684.430380
# QA engineer                                            2900   150  1176.704607
# Research Engineer                                      4000   114  1099.000000
# Sales manager                                          2300   120   635.847059
# Scrum Master                                           4500   370  2355.684211
# Security Specialist                                    4000   300  1783.250000
# Senior Project Manager / Program Manager               9100   200  3562.181818
# Senior QA engineer                                     6000   400  2385.536122
# Senior Software Engineer                               9200   350  3243.200926
# Software Engineer                                      7000   100  1678.630074
# Support                                                3650   138   817.339130
# Sysadmin                                               3000    90   773.542636
# System Architect                                      10000   400  4387.076923
# Talent Researcher                                      1700   100   550.555556
# Team lead                                              7000   300  2836.328947
# Technical Lead                                        18000   500  3664.272000
# Technical writer                                       3000   200  1127.892857

# %% [markdown]
# Создайте описательную статистику с помощью метода describe для нового столбца.

# %%
grouped_position['avg'].describe()
# Out:
# count      32.000000
# mean     1800.566187
# std      1170.804714
# min       482.774752
# 25%       858.532807
# 50%      1528.543434
# 75%      2363.147188
# max      5066.363636
# Name: avg, dtype: float64

# %% [markdown]
# Сохраните полученную таблицу в CSV файл

# %%
table_for_csv = grouped_position[['Зарплата.в.месяц','avg']]

table_for_csv.to_csv('result.csv', index=True)
