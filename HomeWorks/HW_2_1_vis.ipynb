# %% [markdown]
# Прочитайте данные с помощью метода read_html из таблицы "Коефіцієнт народжуваності в регіонах України (1950—2019)" по ссылке

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

url = "https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8#%D0%9D%D0%B0%D1%80%D0%BE%D0%B4%D0%B6%D1%83%D0%B2%D0%B0%D0%BD%D1%96%D1%81%D1%82%D1%8C"

tmp = pd.read_html(url)
df = tmp[8]

# %% [markdown]
# Вывести первые строки таблицы с помощью метода head

# %%
df.head(5)
# Out:
#              Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0              Крим  230.0  206.0  160.0   130    73   126    —    —
# 1         Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2         Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3  Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4          Донецька  271.0  214.0  140.0   109    61    98   82    —

# %% [markdown]
# Определите количество строк и столбцов в датафрейме (атрибут shape)

# %%
df.shape
# Out:
# (28, 9)

# %% [markdown]
# Замените в таблице значения "—" на значения NaN

# %%
df = df.replace(['—'], np.nan)

# %%
df
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0                Крим  230.0  206.0  160.0   130    73   126  NaN  NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2           Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4            Донецька  271.0  214.0  140.0   109    61    98   82  NaN
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120   79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146  104
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122   88
# 9            Київська  204.0  189.0  156.0   123    73   122  121   80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108   68
# 11          Луганська  262.0  235.0  144.0   116    62    96   51  NaN
# ...

# %% [markdown]
# Определите типы всех столбцов с помощью dataframe.dtypes

# %%
df.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014       object
# 2019       object
# dtype: object

# %% [markdown]
# Замените типы не числовых колонок на числовые. Подсказка - это колонки где находился символ "—"

# %%
df = df.astype({"2014": float, "2019": float})
df.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014      float64
# 2019      float64
# dtype: object

# %% [markdown]
# Посчитайте, какая доля пропусков содержится в каждой колонке (используйте методы isnull и sum)

# %%
df.isna().sum()
# Out:
# Регіон    0
# 1950      2
# 1960      1
# 1970      1
# 1990      0
# 2000      0
# 2012      0
# 2014      2
# 2019      4
# dtype: int64

# %% [markdown]
# ***Візуалізація пропусків***

# %%
data = df.isna().sum()
sns.lineplot(data=data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Удалите из таблицы данные по всей стране, последняя строчка таблицы

# %%
df = df.iloc[:-1].copy()
df
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012   2014   2019
# 0                Крим  230.0  206.0  160.0   130    73   126    NaN    NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109.0   76.0
# 2           Волинська  247.0  250.0  179.0   153   112   148  141.0  101.0
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111.0   71.0
# 4            Донецька  271.0  214.0  140.0   109    61    98   82.0    NaN
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120.0   79.0
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146.0  104.0
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106.0   68.0
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122.0   88.0
# 9            Київська  204.0  189.0  156.0   123    73   122  121.0   80.0
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108.0   68.0
# ...

# %% [markdown]
# Замените отсутствующие данные в столбцах средними значениями по этим столбцам (метод fillna)

# %%
mean_colomns = df.mean().to_dict()
df = df.fillna(value=mean_colomns).copy()
df
# Out:
# <ipython-input-64-ca2a22fb47ca>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_colomns = df.mean().to_dict()
#                Регіон    1950        1960   1970  1990  2000  2012    2014  \
# 0                Крим  230.00  206.000000  160.0   130    73   126  111.44
# 1           Вінницька  224.00  192.000000  142.0   124    84   112  109.00
# 2           Волинська  247.00  250.000000  179.0   153   112   148  141.00
# 3    Дніпропетровська  204.00  204.000000  151.0   123    71   112  111.00
# 4            Донецька  271.00  214.000000  140.0   109    61    98   82.00
# 5         Житомирська  261.00  223.000000  159.0   129    89   122  120.00
# 6        Закарпатська  314.00  273.000000  207.0   168   115   151  146.00
# 7          Запорізька  219.00  197.000000  150.0   124    71   106  106.00
# ...

# %% [markdown]
# ***Візуалізація народжуваності за 2000 рік по регіонах***

# %%
data = df
sns.displot(x="2000", y="Регіон", data=data)

# %%
data_pair = df[['1950', '1960',	'1970',	'1990',	'2000',	'2012',	'2014',	'2019']]
data_pair
# Out:
#       1950        1960   1970  1990  2000  2012    2014        2019
# 0   230.00  206.000000  160.0   130    73   126  111.44   80.173913
# 1   224.00  192.000000  142.0   124    84   112  109.00   76.000000
# 2   247.00  250.000000  179.0   153   112   148  141.00  101.000000
# 3   204.00  204.000000  151.0   123    71   112  111.00   71.000000
# 4   271.00  214.000000  140.0   109    61    98   82.00   80.173913
# 5   261.00  223.000000  159.0   129    89   122  120.00   79.000000
# 6   314.00  273.000000  207.0   168   115   151  146.00  104.000000
# 7   219.00  197.000000  150.0   124    71   106  106.00   68.000000
# 8   243.00  248.000000  182.0   155   103   124  122.00   88.000000
# 9   204.00  189.000000  156.0   123    73   122  121.00   80.000000
# 10  216.00  171.000000  145.0   126    79   110  108.00   68.000000
# 11  262.00  235.000000  144.0   116    62    96   51.00   80.173913
# 12  234.00  240.000000  171.0   140    91   119  119.00   87.000000
# ...

# %% [markdown]
# ***Візуалізація народжуваності за весь період***

# %%
data_pair = df[['1950', '1960',	'1970',	'1990',	'2000',	'2012',	'2014',	'2019']]
sns.heatmap(data_pair)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Получите список регионов, где уровень рождаемости в 2019 году был выше среднего по Украине

# %%
mean_Ukraine_2019 = df['2019'].mean()
regions = df[(df['2019']>mean_Ukraine_2019)]
list_regions = regions['Регіон'].to_list()
list_regions
# Out:
# ['Волинська',
#  'Закарпатська',
#  'Івано-Франківська',
#  'Львівська',
#  'Одеська',
#  'Рівненська',
#  'Херсонська',
#  'Чернівецька',
#  'Київ']

# %% [markdown]
# В каком регионе была самая высокая рождаемость в 2014 году?

# %%
high_fertility_2014 = df['2014'].max()
high_fertility_2014_region = df[(df['2014']==high_fertility_2014)]
region_name = high_fertility_2014_region['Регіон'].to_list()[0]
region_name
# Out:
# 'Рівненська'

# %% [markdown]
# Постройте столбцовую диаграмму рождаемости по регионам в 2019 году

# %%
list_regions = df['Регіон'].to_list()
grafic = df[["2019"]].plot(kind = 'bar')
grafic.set_xticklabels(list_regions)
plt.show()
